# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
path = "/Users/macbookpro/Documents/GitHub/Diabetes_Time_Series/data-01" ## --> Data from Univeristy of California
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARMA
import warnings # Supress warnings 
warnings.filterwarnings('ignore')
from statsmodels.graphics.gofplots import qqplot
from statsmodels.stats.diagnostic import acorr_ljungbox

# %%
data_init = np.array(pd.read_table(path, sep="\t"))
value_sugar = [58,59,60,61,62,63,64]
id_sugar = np.array([data_init[i,2] in value_sugar for i in range(len(data_init))])
data = np.array(data_init[id_sugar,3], dtype=float)
plt.plot(data, '-o');
plt.xlabel("Time")
plt.title("Blood Glucose Measurement");

# %%
ldata = np.log(data) ## Reducing variability of data
plt.plot(ldata, '-o');
plt.xlabel("Time")
plt.title("Transformed data");

# %%
dldata = np.array([ldata[i]-ldata[i+1] for i in range(len(ldata)-1)]) ## Differentiated serie
plt.plot(dldata, '-o');
plt.xlabel("Time")
plt.title("Transformed data");

# %%
plot_acf(dldata), plot_pacf(dldata) ## --> Suggest MA(2)
# Out:
# (<Figure size 432x288 with 1 Axes>, <Figure size 432x288 with 1 Axes>)

# %%
models = [ARMA(dldata, order=(i,j)).fit() for i in range(3) for j in range(3)]
for model in models:
    print("*"*10)
    print(model.summary())
model = models[2] ## --> Best model (MA(2))
# Out:
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(0, 0)   Log Likelihood                -270.357
# Method:                           css   S.D. of innovations              0.617
# Date:                Fri, 31 Mar 2023   AIC                            544.715
# Time:                        17:40:48   BIC                            552.047
# Sample:                             0   HQIC                           547.653
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.036      0.008      0.994      -0.071       0.071
# ==============================================================================
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(0, 1)   Log Likelihood                -186.963
# Method:                       css-mle   S.D. of innovations              0.458
# Date:                Fri, 31 Mar 2023   AIC                            379.926
# Time:                        17:40:48   BIC                            390.925
# Sample:                             0   HQIC                           384.333
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -1.015      0.310      -0.001       0.000
# ma.L1.y       -1.0000      0.013    -74.417      0.000      -1.026      -0.974
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(0, 2)   Log Likelihood                -185.206
# Method:                       css-mle   S.D. of innovations              0.455
# Date:                Fri, 31 Mar 2023   AIC                            378.413
# Time:                        17:40:48   BIC                            393.079
# Sample:                             0   HQIC                           384.289
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -0.905      0.365      -0.001       0.000
# ma.L1.y       -0.8711      0.069    -12.575      0.000      -1.007      -0.735
# ma.L2.y       -0.1289      0.068     -1.887      0.059      -0.263       0.005
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2           -7.7591           +0.0000j            7.7591            0.5000
# -----------------------------------------------------------------------------
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(1, 0)   Log Likelihood                -247.438
# Method:                       css-mle   S.D. of innovations              0.569
# Date:                Fri, 31 Mar 2023   AIC                            500.875
# Time:                        17:40:48   BIC                            511.875
# Sample:                             0   HQIC                           505.283
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.024      0.058      0.954      -0.046       0.049
# ar.L1.y       -0.3835      0.054     -7.053      0.000      -0.490      -0.277
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.6076           +0.0000j            2.6076            0.5000
# -----------------------------------------------------------------------------
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(1, 1)   Log Likelihood                -185.672
# Method:                       css-mle   S.D. of innovations              0.456
# Date:                Fri, 31 Mar 2023   AIC                            379.344
# Time:                        17:40:48   BIC                            394.010
# Sample:                             0   HQIC                           385.221
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -0.920      0.358      -0.001       0.000
# ar.L1.y        0.0944      0.059      1.609      0.108      -0.021       0.209
# ma.L1.y       -1.0000      0.012    -83.935      0.000      -1.023      -0.977
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           10.5912           +0.0000j           10.5912            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(1, 2)   Log Likelihood                -183.357
# Method:                       css-mle   S.D. of innovations              0.452
# Date:                Fri, 31 Mar 2023   AIC                            376.714
# Time:                        17:40:48   BIC                            395.046
# Sample:                             0   HQIC                           384.060
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -0.957      0.339      -0.001       0.000
# ar.L1.y       -0.5206      0.242     -2.149      0.032      -0.995      -0.046
# ma.L1.y       -0.3437      0.215     -1.602      0.109      -0.764       0.077
# ma.L2.y       -0.6563      0.214     -3.062      0.002      -1.076      -0.236
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.9208           +0.0000j            1.9208            0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2           -1.5237           +0.0000j            1.5237            0.5000
# -----------------------------------------------------------------------------
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(2, 0)   Log Likelihood                -220.682
# Method:                       css-mle   S.D. of innovations              0.519
# Date:                Fri, 31 Mar 2023   AIC                            449.364
# Time:                        17:40:48   BIC                            464.029
# Sample:                             0   HQIC                           455.240
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.016      0.097      0.922      -0.029       0.032
# ar.L1.y       -0.5404      0.054    -10.077      0.000      -0.646      -0.435
# ar.L2.y       -0.4124      0.054     -7.681      0.000      -0.518      -0.307
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.6553           -1.4127j            1.5573           -0.3191
# AR.2           -0.6553           +1.4127j            1.5573            0.3191
# -----------------------------------------------------------------------------
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(2, 1)   Log Likelihood                -183.118
# Method:                       css-mle   S.D. of innovations              0.451
# Date:                Fri, 31 Mar 2023   AIC                            376.237
# Time:                        17:40:48   BIC                            394.569
# Sample:                             0   HQIC                           383.582
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -1.097      0.273      -0.001       0.000
# ar.L1.y        0.1056      0.058      1.810      0.070      -0.009       0.220
# ar.L2.y       -0.1334      0.059     -2.272      0.023      -0.248      -0.018
# ma.L1.y       -1.0000      0.014    -69.257      0.000      -1.028      -0.972
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.3957           -2.7093j            2.7381           -0.2269
# AR.2            0.3957           +2.7093j            2.7381            0.2269
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# **********
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  289
# Model:                     ARMA(2, 2)   Log Likelihood                -182.600
# Method:                       css-mle   S.D. of innovations              0.451
# Date:                Fri, 31 Mar 2023   AIC                            377.199
# Time:                        17:40:48   BIC                            399.198
# Sample:                             0   HQIC                           386.014
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.000     -1.053      0.292      -0.001       0.000
# ar.L1.y       -0.2360      0.301     -0.784      0.433      -0.826       0.354
# ar.L2.y       -0.1048      0.073     -1.430      0.153      -0.249       0.039
# ma.L1.y       -0.6505      0.301     -2.164      0.030      -1.240      -0.061
# ma.L2.y       -0.3494      0.300     -1.163      0.245      -0.938       0.239
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1253           -2.8760j            3.0883           -0.3094
# AR.2           -1.1253           +2.8760j            3.0883            0.3094
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2           -2.8616           +0.0000j            2.8616            0.5000
# -----------------------------------------------------------------------------

# %%
prediction = model.predict(end=50) ## Prediction of the future

# %%
dldata_predict = np.concatenate((dldata, prediction))
plt.plot(np.arange(len(dldata)), dldata, '-ob', label = "data");
plt.plot(np.arange(len(dldata), len(dldata_predict)), prediction, '-or', label = "prediction");
plt.xlabel("Time")
plt.title("Time serie prediction");
plt.legend();

# %%
replace_prediction = model.predict(start = len(dldata)-50+1, end=len(dldata)) ## Prediction of the end of the data

# %%
dldata_replace_predict = np.concatenate((dldata[:-50], replace_prediction))
plt.plot(dldata, '-ob', alpha=0.3, label = "data");
plt.plot(np.arange(len(dldata[:-50]), len(dldata_replace_predict)),
         replace_prediction, '-om', label = "preditcion");
plt.xlabel("Time")
plt.title("Prediction of the end of the data");
plt.legend();

# %%
plt.plot(np.arange(len(dldata[:-50]), len(dldata_replace_predict)),
         replace_prediction, '-om', alpha=0.7, label = "prediction");
plt.plot(np.arange(len(dldata[:-50]), len(dldata_replace_predict)),
         dldata[-50:], '-ob', alpha=0.7, label = "data");
plt.xlabel("Time")
plt.title("Zoom");
plt.legend();

# %%
residuals = (replace_prediction-dldata[-50:])
qqplot(residuals, line="45")
plt.title("QQ-plot of residuals"); ## --> Samples quantiles are near the theorical quantile of a white noise (the line)
# Out:
# Text(0.5, 1.0, 'QQ-plot of residuals')

# %%
_, pvalues = acorr_ljungbox(residuals, lags = 49)
plt.scatter(range(1,len(pvalues)+1),pvalues);
plt.plot([0.05]*(len(pvalues)+2), '--r', label = "5% threshold");
plt.xlim(0,len(pvalues)+1);
plt.xlabel("Lag")
plt.legend();
plt.title("P-value Ljung-Box"); ## --> All p-values are greater than 5% which means our prediction is surely correct

# %%
plot_acf(residuals), plot_pacf(residuals) ## --> Suggest a white noise which means that our model is correct
# Out:
# (<Figure size 432x288 with 1 Axes>, <Figure size 432x288 with 1 Axes>)
